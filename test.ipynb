# %%
import data_generator
import torch

# %%
a = data_generator.generate(3, 10)
print(a)
# Out:
# tensor([[[   inf,    inf,    inf,    inf,    inf,    inf,    inf,    inf,
#              inf,    inf],
#          [2.0816, 3.2339, 4.8254, 4.0311, 4.0435, 4.7693, 3.5637, 2.4667,
#           2.4352, 2.1749],
#          [4.3714, 4.3657, 3.3603, 3.4501, 3.5918, 3.0447, 3.3139, 3.2070,
#           1.8425, 2.6529]],
#
#         [[2.0966, 2.0487, 2.4629, 3.8936, 4.4460, 4.3189, 3.6087, 2.6696,
#           1.8658, 2.1990],
#          [   inf,    inf,    inf,    inf,    inf,    inf,    inf,    inf,
#              inf,    inf],
#          [2.4973, 1.5126, 2.2662, 3.1800, 4.0598, 4.8498, 5.1058, 4.9772,
#           2.7241, 1.7244]],
#
#         [[2.7670, 2.7910, 2.8988, 4.3177, 4.3243, 4.8202, 3.0839, 2.1806,
#           2.2873, 2.4162],
#          [3.0801, 3.4104, 5.2100, 4.1981, 3.9520, 3.8188, 3.8640, 3.0613,
#           3.0050, 3.3327],
#          [   inf,    inf,    inf,    inf,    inf,    inf,    inf,    inf,
#              inf,    inf]]])

# %%
import matplotlib.pyplot as plt

# Define the indices i and j
i, j = 2, 1  # Replace with the desired indices

# Extract the data for the given ij pair
data = a[i, j, :].numpy()

# Plot the data
plt.plot(data)
plt.title(f"Plot for indices i={i}, j={j}")
plt.xlabel("Index")
plt.ylabel("Value")
plt.show()

# %%
print(data_generator.shortest_paths_by_slice(a))
# Out:
# tensor([[[0.0000, 2.0816, 4.3714],
#          [2.0966, 0.0000, 2.4973],
#          [2.7670, 3.0801, 0.0000]],
#
#         [[0.0000, 3.2339, 4.3657],
#          [2.0487, 0.0000, 1.5126],
#          [2.7910, 3.4104, 0.0000]],
#
#         [[0.0000, 4.8254, 3.3603],
#          [2.4629, 0.0000, 2.2662],
#          [2.8988, 5.2100, 0.0000]],
#
#         [[0.0000, 4.0311, 3.4501],
#          [3.8936, 0.0000, 3.1800],
#          [4.3177, 4.1981, 0.0000]],
#
#         [[0.0000, 4.0435, 3.5918],
#          [4.4460, 0.0000, 4.0598],
#          [4.3243, 3.9520, 0.0000]],
#
#         [[0.0000, 4.7693, 3.0447],
#          [4.3189, 0.0000, 4.8498],
#          [4.8202, 3.8188, 0.0000]],
#
#         [[0.0000, 3.5637, 3.3139],
#          [3.6087, 0.0000, 5.1058],
#          [3.0839, 3.8640, 0.0000]],
#
#         [[0.0000, 2.4667, 3.2070],
#          [2.6696, 0.0000, 4.9772],
#          [2.1806, 3.0613, 0.0000]],
#
#         [[0.0000, 2.4352, 1.8425],
#          [1.8658, 0.0000, 2.7241],
# ...
